# %%
# %%time
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import cv2
# Out:
# Wall time: 1.26 s

# %%
img = cv2.imread('Signature.jpg')

# %%
# Taking a matrix of size 5 as the kernel
kernel = np.ones((5,5), np.uint8)
img_dilation = cv2.dilate(img, kernel, iterations=1)
cv2.imwrite('dilated_sign_.jpg', img_dilation)
# Out:
# True

# %%
image = cv2.imread('dilated_sign_.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Set threshold level
threshold_level = 45
# Find coordinates of all pixels below threshold
coords = np.column_stack(np.where(gray < threshold_level))

print(coords.shape)
# Out:
# (30163, 2)

# %%
plt.style.use('seaborn-dark-palette')

# %%
fig, ax = plt.subplots()
ax.grid(False)
fig.set_size_inches(6,9)
ax.plot(coords[:,0], coords[:,1], '.', color='royalblue')
ax.yaxis.set_visible(False)
#fig.savefig('pixel_sign.jpg')

# %%
fig, ax = plt.subplots()
ax.grid(False)
fig.set_size_inches(6,9)
ax.plot(coords[:,0], coords[:,1], color='royalblue')
ax.yaxis.set_visible(False)
#fig.savefig('plot_of_failure.jpg')
